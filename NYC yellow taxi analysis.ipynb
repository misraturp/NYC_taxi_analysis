# %%
import pandas as pd

# %matplotlib inline

# %%
taxi_data = pd.concat([taxi_jan_2019])

# %%
print(taxi_data.shape)
taxi_data.head()
# Out:
# (7667792, 18)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5           1                  N           151           239
# 1            2.6           1                  N           239           246
# 2            0.0           1                  N           236           236
# 3            0.0           1                  N           193           193
# 4            0.0           2                  N           193           193
#
# ...

# %%
taxi_data.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge'],
#       dtype='object')

# %%
taxi_data = taxi_data[['tpep_pickup_datetime', 'tpep_dropoff_datetime',
       'passenger_count', 'trip_distance', 'RatecodeID','PULocationID',
       'DOLocationID', 'payment_type',  'total_amount']]

# %%
taxi_data.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20                1            1.5
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59                1            2.6
# 2  2018-12-21 13:48:30   2018-12-21 13:52:40                3            0.0
# 3  2018-11-28 15:52:25   2018-11-28 15:55:45                5            0.0
# 4  2018-11-28 15:56:57   2018-11-28 15:58:33                5            0.0
#
#    RatecodeID  PULocationID  DOLocationID  payment_type  total_amount
# 0           1           151           239             1          9.95
# 1           1           239           246             1         16.30
# 2           1           236           236             1          5.80
# 3           1           193           193             2          7.55
# 4           2           193           193             2         55.55

# %%
taxi_data.hist(figsize=(20,10), bins=60)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119357150>,
# ...
#       dtype=object)

# %%
taxi_data['RatecodeID'].value_counts()
# Out:
# 1     7430139
# 2      166090
# 5       54569
# 3       11801
# 4        4895
# 99        252
# 6          46
# Name: RatecodeID, dtype: int64

# %%
taxi_data.reset_index().plot(kind='scatter', y='total_amount', x='index', figsize=(20,10))

# %%
taxi_data[taxi_data['total_amount']<500].reset_index().plot(kind='scatter', y='total_amount', x='index', figsize=(20,10))

# %%
taxi_data[taxi_data['total_amount']==0]
# Out:
#         tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3552     2019-01-01 00:18:46   2019-01-01 00:18:46                1
# 9138     2019-01-01 00:41:47   2019-01-01 00:41:47                1
# 13256    2019-01-01 00:19:38   2019-01-01 00:20:35                1
# 13257    2019-01-01 00:43:34   2019-01-01 00:43:34                1
# 13258    2019-01-01 00:02:52   2019-01-01 00:02:52                1
# ...                      ...                   ...              ...
# 7656282  2019-01-31 20:56:35   2019-01-31 22:37:18                1
# 7667788  2019-01-31 23:32:03   2019-01-31 23:33:11                1
# 7667789  2019-01-31 23:36:36   2019-01-31 23:36:40                1
# 7667790  2019-01-31 23:14:53   2019-01-31 23:15:20                1
# 7667791  2019-01-31 23:12:49   2019-01-31 23:14:08                1
#
#          trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# ...

# %%
taxi_data[taxi_data['total_amount']<0]
# Out:
#         tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 663      2019-01-01 00:32:56   2019-01-01 00:33:35                2
# 2402     2019-01-01 00:14:18   2019-01-01 00:40:55                1
# 2541     2019-01-01 00:31:27   2019-01-01 00:42:39                1
# 2544     2019-01-01 00:45:57   2019-01-01 00:46:07                1
# 2547     2019-01-01 00:48:35   2019-01-01 00:49:59                1
# ...                      ...                   ...              ...
# 7665612  2019-01-31 23:24:31   2019-01-31 23:25:52                1
# 7666343  2019-01-31 23:36:37   2019-01-31 23:37:44                1
# 7666452  2019-01-31 23:08:30   2019-01-31 23:19:27                2
# 7666601  2019-01-31 23:42:48   2019-01-31 23:48:23                1
# 7667014  2019-01-31 23:52:30   2019-01-31 23:53:26                1
#
#          trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# ...

# %%
taxi_data_filtered = taxi_data[(taxi_data['total_amount']>=0)&(taxi_data['total_amount']<400)]

# %%
taxi_data_filtered.shape
# Out:
# (7660542, 9)

# %%
taxi_data_filtered.dtypes
# Out:
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# RatecodeID                 int64
# PULocationID               int64
# DOLocationID               int64
# payment_type               int64
# total_amount             float64
# dtype: object

# %%
taxi_data_filtered['tpep_pickup_datetime'] = pd.to_datetime(taxi_data_filtered['tpep_pickup_datetime'])
taxi_data_filtered['tpep_dropoff_datetime'] = pd.to_datetime(taxi_data_filtered['tpep_dropoff_datetime'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
taxi_data_filtered['RatecodeID'] = taxi_data_filtered['RatecodeID'].astype(str)
taxi_data_filtered['PULocationID'] = taxi_data_filtered['PULocationID'].astype(str)
taxi_data_filtered['DOLocationID'] = taxi_data_filtered['DOLocationID'].astype(str)
taxi_data_filtered['payment_type'] = taxi_data_filtered['payment_type'].astype(str)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
taxi_data_filtered.dtypes
# Out:
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                       object
# PULocationID                     object
# DOLocationID                     object
# payment_type                     object
# total_amount                    float64
# dtype: object
